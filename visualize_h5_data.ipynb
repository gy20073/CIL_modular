# %%
import h5py
import numpy as np
path = "./data2018620_Unknown_2/data_00000.h5"
f=h5py.File(path, "r")

# %%
print(list(f.keys()))
# Out:
# ['depth', 'labels', 'rgb', 'targets']

# %%
depth = np.array(f['depth'])
print(depth.shape)
labels = np.array(f['labels'])
print(labels.shape)
rgb = np.array(f['rgb'])
print(rgb.shape)
targets = np.array(f['targets'])
print(targets.shape)
# Out:
# (200, 88, 200, 3)
# (200, 88, 200, 1)
# (200, 88, 200, 3)
# (200, 31)

# %%
i=0

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
i += 1
imgplot = plt.imshow(rgb[i, :, :,:])

# %%
imgplot = plt.imshow(depth[199, :, :,:])

# %%
imgplot = plt.imshow(np.squeeze(labels[199, :, :,:]))

# %%
print(targets[0,:])
# Out:
# [ 6.6183819e-03  7.5000000e-01  0.0000000e+00  0.0000000e+00
#   0.0000000e+00  6.6183819e-03  7.5000000e-01  0.0000000e+00
#   1.4291994e+04  3.3045961e+04  1.0652908e-04  0.0000000e+00
#   0.0000000e+00  0.0000000e+00  0.0000000e+00  0.0000000e+00
#  -1.3729952e-04  0.0000000e+00 -9.4861194e-09  2.1474836e+09
#   8.3700000e+03  1.0000000e+00  0.0000000e+00  3.7550926e-05
#   2.0000000e+00  0.0000000e+00 -3.0000000e+01  1.5306486e+04
#   3.3054355e+04  1.6911791e+04  3.3057031e+04]
